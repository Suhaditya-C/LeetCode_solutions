# %% [markdown]
# # 1007. Minimum Domino Rotations For Equal Row
#
# In a row of dominoes, tops[i] and bottoms[i] represent the top and bottom halves of the ith domino. (A domino is a tile with two numbers from 1 to 6 - one on each half of the tile.)
#
# We may rotate the ith domino, so that tops[i] and bottoms[i] swap values.
#
# Return the minimum number of rotations so that all the values in tops are the same, or all the values in bottoms are the same.
#
# If it cannot be done, return -1.
#
#
#
# Example 1:
#
# ![image.png](attachment:image.png)
#
# Input: tops = [2,1,2,4,2,2], bottoms = [5,2,6,2,3,2]
# Output: 2
# Explanation:
# The first figure represents the dominoes as given by tops and bottoms: before we do any rotations.
# If we rotate the second and fourth dominoes, we can make every value in the top row equal to 2, as indicated by the second figure.
# Example 2:
#
# Input: tops = [3,5,1,2,3], bottoms = [3,6,3,3,4]
# Output: -1
# Explanation:
# In this case, it is not possible to rotate the dominoes to make one row of values equal.
#
#
# Constraints:
#
# 2 <= tops.length <= 2 * 104
# bottoms.length == tops.length
# 1 <= tops[i], bottoms[i] <= 6

# %% [markdown]
# ## Solution:
# The desired result can have either all tops[0] or bottoms[0]. Accordingly we have to check if each of these two numbers can be formed by rotation by checking through each of these two arrays i.e. we have to run 4 loops

# %%
tops = [1,2,1,1,1,2,2,2]; bottoms = [2,1,2,2,2,2,2,2]
top=tops[0]
bottom=bottoms[0]
cnt1,cnt2,cnt3,cnt4=0,0,0,0
for i in range(1,len(tops)):
    if tops[i]!=top:
        if bottoms[i]==top:
            cnt1+=1
        else:
            cnt1=float('inf')
            break
for i in range(len(tops)):
    if tops[i]!=bottom:
        if bottoms[i]==bottom:
            cnt2+=1
        else:
            cnt2=float('inf')
            break
for i in range(1,len(bottoms)):
    if bottoms[i]!=bottom:
        if tops[i]==bottom:
            cnt3+=1
        else:
            cnt3=float('inf')
            break
for i in range(len(bottoms)):
    if bottoms[i]!=top:
        if tops[i]==top:
            cnt4+=1
        else:
            cnt4=float('inf')
            break
res=min(cnt1,cnt2,cnt3,cnt4) 
res if res!=float('inf') else -1
# Out:
# 1

# %%
cnt1,cnt2,cnt3,cnt4
# Out:
# (inf, 4, inf, inf)
